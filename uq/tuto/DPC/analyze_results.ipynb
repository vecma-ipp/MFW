# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
D = pd.read_csv('results.log')
D.columns
# Out:
# Index(['N1', 'N2', 'N3', 's2', 's3', 'd2', 'd3', 'alpha', 'dt', 'NITER',
#        'flux_mean', 'flux_std', 'flux_ref', 'Te_0_mean_all', 'Te_0_std_all',
#        'Te_0_mean_50%', 'Te_0_std_50%'],
#       dtype='object')

# %%
D[(D.alpha==0.01) & (D.dt==0.01)].plot(x='s2', y=['Te_0_mean_50%', 'Te_0_std_50%'], 
                      style='o', logx=True, logy=True,
                      title='alpha=0.01, dt=0.01');

# %%
D[D.s2==1.0].plot(x='alpha', y=['Te_0_mean_50%', 'Te_0_std_50%'], 
                  style='o', logx=True, logy=False, 
                  title='s2=s3 = 1.0');

# %%
D[D.s2==0.2].plot(x='alpha', y=['Te_0_mean_50%', 'Te_0_std_50%'], 
                  style='o', logx=True, logy=False, 
                  title='s2=s3 = 0.2');

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i, g in D[D.s2==0.2].groupby('dt'):
    g.plot(x='alpha', y='Te_0_std_50%', 
           style='o', logx=True, logy=True, ax=ax, label='dt=%s' % (i), 
           title='s2=s3 = 0.2')
plt.ylabel('Te_0_std_50%');

# %%
D[D.s2==0.2][['s2', 's3', 'alpha', 'dt', 'NITER', 'Te_0_mean_50%', 'Te_0_std_50%']]
# Out:
#      s2   s3   alpha     dt  NITER  Te_0_mean_50%  Te_0_std_50%
# 0   0.2  0.2  0.0100  0.010   1000    4148.267167    197.276089
# 1   0.2  0.2  0.0100  0.010   1000    4222.690459    198.495257
# 26  0.2  0.2  0.1000  0.010   1000    3991.700214    414.174735
# 27  0.2  0.2  0.1000  0.010   1000    3983.573684    417.947373
# 28  0.2  0.2  0.0010  0.010   1000    4286.176702    127.563135
# 29  0.2  0.2  0.0010  0.010   1000    4275.540795    103.673553
# 30  0.2  0.2  0.0010  0.100    100    4534.735875    284.800604
# 31  0.2  0.2  0.0010  0.100    100    4472.075281    131.484674
# 32  0.2  0.2  0.0100  0.100    100    4027.136402    328.780921
# 33  0.2  0.2  0.0100  0.100    100    4170.956827    369.759585
# 34  0.2  0.2  0.1000  0.100    100    4489.734714    871.762244
# 35  0.2  0.2  0.1000  0.100    100    4018.242596    962.139016
# 36  0.2  0.2  0.1000  0.001  10000    3926.176479    134.077563
# 37  0.2  0.2  0.1000  0.001  10000    3913.704462    124.190669
# 38  0.2  0.2  0.0100  0.001  10000    4202.526456     84.251861
# 39  0.2  0.2  0.0100  0.001  10000    4246.097355     77.264063
# 40  0.2  0.2  0.0010  0.001  10000    4270.496397     67.540678
# 41  0.2  0.2  0.0010  0.001  10000    4277.709966     57.838687
# 42  0.2  0.2  0.0001  0.001  10000    4260.227342     34.924688
# 43  0.2  0.2  0.0001  0.001  10000    4259.566088     39.314552
# 44  0.2  0.2  0.0001  0.001  10000    4278.618593     48.149975
# 45  0.2  0.2  0.0001  0.001  10000    4257.375719     32.926945
# 46  0.2  0.2  0.0100  0.010   1000    4178.834973    193.643880
# 47  0.2  0.2  0.0100  0.010   1000    4184.371318    215.601704
